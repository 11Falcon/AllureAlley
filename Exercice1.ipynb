# %%
#Les catalogues



catalogue_enfants = {
    "Vêtements": {"Filles":{
        "Robes" : {"Robes de fête","Robes casual","Robes de nuit"},
        "Tops" : {"T-shirts","Blouses","Pulls"},
        "Pantalons" : {"Jeans","Leggings","Shorts"},
        "Chaussures" : {"Baskets","Sandales","Bottes"},
        "Accessoires" : {"Chapeaux","Écharpes","Bijoux pour enfants"}
        },
        "Garcons":{
        "Short" : {"Shorts de sport","Short en jean","Bermudas"},
        "T-Shirts" : {"T-shirts à manches courtes","T-shirts à manches longues","Polos"},
        "Pantalons" : {"Jeans","Pantalons de sport","Pantalons décontractés"},
        "Chaussures" : {"Baskets","Sandales","Bottes"},
        "Accessoires" : {"Chapeaux","Écharpes","Ceintures"}
        },
        },  
    "Jouets": {"Par âge":{"0-2 ans":{"Jouets à tirer","Jouets àmusicaux","Jouets à empiler"},
                          "3-5 ans":{"jeux d'apprentissage", "Puzzles","jeux créatif"},
                          "6-8 ans":{"jeux de société","jeux de construction","jeux scientifiques"},
                          "9-12 ans":{"kits de science","jouet électroniques","jeux de stratégie"}
                          },
               "Par type":{"Educatifs" : {"Livrable interractif","Kits d'apprentissage des langues","Jeu mathametique"},
                           "Action" : {"Figurines","Jouets à lancer","Voitures télécommandées"},
                           "Créativité" : {"Kits d'art","Perles et bijoux","Jouets de musique"}
                           }
               },
    "Fournitures Scolaires": {"Par âge":{"Maternelle":{"Crayons et feutres Ciseaux","Ciseaux de sécurité","Cahier d'activité"},
                                            "Ecole Primaire":{"Fourniture d'écriture","Calculatrice simples","Cahier et dossier"},
                                            "Collège":{"Calculatrice scientifique","Fourniture d'art","Organisateurs et agendas"}
                                            },
                              "Par type":{"Ecriture" : {"Crayons","Stylos","Marqueurs"},
                                          "Organisation" : {"Classeurs","Etiquettes","Sacs à dos"},
                                          "Art et Création" : {"Peinture","Papier de construction","Colle en ciseaux"}
                                          }
                              },
}

catalogue_noel = {
    "Cadeaux": {
        "Pour Elle": {
            "Bijoux": {"Colliers", "Bracelets", "Boucles d'oreilles", "Bagues"},
            "Beauté": {"Maquillage", "Parfums", "Soins de la peau", "Soins des cheveux"},
            "Mode": {"Vêtements", "Chaussures", "Sacs à main", "Accessoires"}
        },
        "Pour Lui": {
            "Tech": {"Gadgets", "Jeux vidéo", "Audio", "Informatique"},
            "Mode": {"Vêtements", "Chaussures", "Montres", "Accessoires"},
            "Sports & Loisirs": {"Équipement sportif", "Plein air", "Fitness", "Jeux de société"}
        },
        "Pour Enfants": {
            "Jouets": {"Jeux éducatifs", "Poupées et peluches", "Jeux de construction", "Jeux de plein air"},
            "Vêtements": {"Filles", "Garçons"},
            "Chaussures": {"Filles", "Garçons"},
            "Livres pour enfants": {"Éducatifs", "Romans jeunesse", "BD", "Albums illustrés"}
        }
    },
    "Décoration de Noël": {
        "Décorations d'Intérieur": {
            "Ornements": {"Boules", "Guirlandes", "Figurines", "Bas de Noël"},
            "Lumières": {"Guirlandes lumineuses", "Bougies", "Lanternes", "Lampes décoratives"},
            "Décoration de table": {"Nappes de Noël", "Vaisselle de Noël", "Centres de table", "Serviettes de Noël"},
            "Décoration de la pièce": {"Rideaux de Noël", "Coussins de Noël", "Tapis de Noël", "Couvertures de Noël"}
        },
        "Décorations d'Extérieur": {
            "Lumières": {"Guirlandes lumineuses", "Lanternes", "Projecteurs de Noël", "Lampes décoratives"},
            "Décorations du jardin": {"Statues de Noël", "Bannières de Noël", "Guirlandes extérieures", "Ornements pour arbres de Noël extérieurs"},
            "Décoration de la porte d'entrée": {"Couronnes de Noël", "Tapis de bienvenue de Noël", "Bannières de porte de Noël", "Cloches de porte de Noël"}
        }
    },
    "Gastronomie de Noël": {
        "Pâtisserie": {"Gâteaux de Noël", "Biscuits de Noël", "Bonbons de Noël", "Kit pâtisserie de Noël"},
        "Boissons": {"Vin de Noël", "Chocolat chaud de Noël", "Café de Noël", "Thé de Noël"},
        "Paniers Gourmet": {"Paniers de chocolat", "Paniers de fruits et noix", "Paniers de charcuterie", "Paniers de fromages"}
    }
}


catalogue_ete = {
    "Prêt-à-porter": {
        "Femmes": {
            "Robes": {
                "Robes de plage", "Robes légères", "Robes à bretelles", "Robes maxi"
            },
            "Tops": {
                "T-shirts", "Débardeurs", "Chemisiers", "Tuniques"
            },
            "Shorts & Jupes": {
                "Shorts en jean", "Shorts de sport", "Jupes courtes", "Jupes longues"
            },
            "Maillots de bain": {
                "Bikinis", "Maillots une pièce", "Tankinis", "Maillots de bain taille plus"
            },
            "Accessoires d'été": {
                "Chapeaux", "Lunettes de soleil", "Sac de plage", "Paréos"
            }
        },
        "Hommes": {
            "Shorts": {
                "Shorts en jean", "Shorts de sport", "Shorts de bain", "Bermudas"
            },
            "T-Shirts & Polos": {
                "T-Shirts à manches courtes", "T-Shirts à manches longues", "Polos", "Débardeurs"
            },
            "Maillots de bain": {
                "Shorts de bain", "Slips de bain", "Boxers de bain", "Maillots de bain taille plus"
            },
            "Accessoires d'été": {
                "Chapeaux", "Lunettes de soleil", "Sacs de plage", "Serviettes de plage"
            }
        },
        "Enfants": {
            "Filles": {
                "Robes", "Tops", "Shorts", "Maillots de bain","Accessoires d'été"
            },
            "Garçons": {
                "T-Shirts & Polos": {
                    "T-Shirts à manches courtes", "T-Shirts à manches longues", "Polos", "Débardeurs"
                },
                "Shorts": {
                    "Shorts en jean", "Shorts de sport", "Bermudas", "Shorts de bain"
                },
                "Maillots de bain": {
                    "Shorts de bain", "Slips de bain", "Boxers de bain", "Maillots de bain pour la natation"
                },
                "Accessoires d'été": {
                    "Chapeaux", "Lunettes de soleil", "Sacs de plage", "Serviettes de plage"
                }
            }
        }
    },
    "Maison & Déco": {
        "Mobilier de jardin": {
            "Chaises": {
                "Chaises longues", "Chaises pliantes", "Chaises de jardin", "Chaises de plage"
            },
            "Tables": {
                "Tables de pique-nique", "Tables de jardin", "Tables pliantes", "Tables de café d'extérieur"
            },
            "Parasols": {
                "Parasols de jardin", "Parasols de plage", "Parasols de table", "Parasols déportés"
            }
        },
        "Barbecue & Accessoires": {}
    }
}

# %%
from openai import OpenAI

client = OpenAI(
    api_key="Your API Key"
)

completion = client.chat.completions.create(
  model="gpt-3.5-turbo",
  messages=[
    {"role": "system", "content": "Vous êtes un assistant utile pour AllureAlley, une entreprise de mode et de décoration d'intérieur. Votre objectif est d'aider à créer une nouvelle structure de catégories unifiée pour leur prochain site d'e-commerce. Utilisez toutes les informations du catalogue pour générer une hiérarchie pertinente et multi-niveaux pour les catégories de produits. Assurez-vous que la nouvelle structure de catégories pour l'e-commerce est conviviale et facilite la navigation sur le site.\n\nVeillez à utiliser tous les produits existants dans le catalogue, sans ajouter de nouveaux produits.\n le catalogue est: Catalogue Été\n\n1. Prêt-à-porter\n\n1.1 Femmes\n\n1.1.1 Robes\n\n1.1.2 Maillots de bain\n\n1.1.3 Accessoires d'été\n\n1.2 Hommes\n\n1.2.1 Shorts\n\n1.2.2 T-Shirts\n\n1.2.3 Accessoires d'été\n\n1.3 Enfants\n\n1.3.1 Filles\n\n1.3.2 Garçons\n\n2. Maison & Déco\n\n2.1 Mobilier de jardin\n\n2.1.1 Chaises\n\n2.1.2 Tables\n\n2.2 Barbecue & Accessoires\n\n2.3 Décoration extérieure\n\nCatalogue Enfants\n\n1. Vêtements\n\n1.1 Filles\n\n1.1.1 Robes\n\n1.1.2 Tops\n\n1.1.3 Chaussures\n\n1.2 Garçons\n\n1.2.1 Shorts\n\n1.2.2 T-Shirts\n\n1.2.3 Chaussures\n\n2. Jouets\n\n2.1 Par âge\n\n2.1.1 0-2 ans\n\n2.1.2 3-5 ans\n\n2.1.3 6-8 ans\n\n2.1.4 9-12 ans\n\n2.2 Par type\n\n2.2.1 Éducatifs\n\n2.2.2 Action\n\n2.2.3 Créativité\n\nCatalogue Noël\n\n1. Cadeaux\n\n1.1 Pour elle\n\n1.1.1 Bijoux\n\n1.1.2 Beauté\n\n1.1.3 Mode\n\n1.2 Pour lui\n\n1.2.1 Tech\n\n1.2.2 Mode\n\n1.2.3 Accessoires\n\n1.3 Pour enfants\n\n1.3.1 Jouets\n\n1.3.2 Vêtements\n\n2. Décoration de Noël\n\n2.1 Décorations d'intérieur\n\n2.1.1 Ornements\n\n2.1.2 Lumières\n\n2.2 Décorations d'extérieur\n\n2.2.1 Lumières\n\n2.2.2 Statues\n"},
    {"role": "user","content": "Générez maintenant le nouveau référentiel de catégories pour le site d'e-commerce d'AllureAlley en utilisant les informations des catalogues été, enfant et Noël."}
  ]
)

print(completion.choices[0].message)
# Out:
# ChatCompletionMessage(content="Voici la nouvelle structure de catégories pour le site d'e-commerce d'AllureAlley :\n\n1. Prêt-à-porter\n   1.1 Femmes\n      1.1.1 Robes\n      1.1.2 Maillots de bain\n      1.1.3 Accessoires d'été\n   1.2 Hommes\n      1.2.1 Shorts\n      1.2.2 T-Shirts\n      1.2.3 Accessoires d'été\n   1.3 Enfants\n      1.3.1 Filles\n         1.3.1.1 Robes\n         1.3.1.2 Tops\n         1.3.1.3 Chaussures\n      1.3.2 Garçons\n         1.3.2.1 Shorts\n         1.3.2.2 T-Shirts\n         1.3.2.3 Chaussures\n\n2. Maison & Déco\n   2.1 Mobilier de jardin\n      2.1.1 Chaises\n      2.1.2 Tables\n   2.2 Barbecue & Accessoires\n   2.3 Décoration extérieure\n\n3. Enfants\n   3.1 Vêtements\n      3.1.1 Filles\n         3.1.1.1 Robes\n         3.1.1.2 Tops\n         3.1.1.3 Chaussures\n      3.1.2 Garçons\n         3.1.2.1 Shorts\n         3.1.2.2 T-Shirts\n         3.1.2.3 Chaussures\n   3.2 Jouets\n      3.2.1 Par âge\n         3.2.1.1 0-2 ans\n         3.2.1.2 3-5 ans
# ...

# %%
import pandas as pd
#save a text in a text file

text_file = open("P1.txt", "w")
text_file.write(str(completion.choices[0].message.content))
text_file.write(str(completion.choices[0]))
text_file.close()
